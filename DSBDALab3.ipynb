# %%
import pandas as pd
import numpy as np

d1 = pd.DataFrame({'RN':[1,2,3,4,5], 'SNAME':['A','B','C','D','E']})
d2 = pd.DataFrame({'RN':[1,2,3,4,5], 'Marks':[24,28,19,25,29]})
pd.merge(d1,d2,on = 'RN')
# Out:
#    RN SNAME  Marks
# 0   1     A     24
# 1   2     B     28
# 2   3     C     19
# 3   4     D     25
# 4   5     E     29

# %%
df = pd.DataFrame({'RN':[1,2,3,4,5], 'SNAME':['A','B','C','D','E'], 'Marks':[24,28,19,25,29]})
df.pivot(index='RN', columns='SNAME', values='Marks')
# Out:
# SNAME     A     B     C     D     E
# RN
# 1      24.0   NaN   NaN   NaN   NaN
# 2       NaN  28.0   NaN   NaN   NaN
# 3       NaN   NaN  19.0   NaN   NaN
# 4       NaN   NaN   NaN  25.0   NaN
# 5       NaN   NaN   NaN   NaN  29.0

# %%
df1 = pd.DataFrame({'RN':[1,2,None,4,None], 'SNAME':['A',None,'C','D','E'], 'Marks':[24,28,19,25,None]})
df1
# Out:
#     RN SNAME  Marks
# 0  1.0     A   24.0
# 1  2.0  None   28.0
# 2  NaN     C   19.0
# 3  4.0     D   25.0
# 4  NaN     E    NaN

# %%
df1.bfill(axis=0)
# Out:
#     RN SNAME  Marks
# 0  1.0     A   24.0
# 1  2.0     C   28.0
# 2  4.0     C   19.0
# 3  4.0     D   25.0
# 4  NaN     E    NaN

# %%
df1.bfill(axis=1)
# Out:
#     RN SNAME Marks
# 0  1.0     A  24.0
# 1  2.0  28.0  28.0
# 2    C     C  19.0
# 3  4.0     D  25.0
# 4    E     E   NaN

# %%
df1.ffill(axis=1)
# Out:
#     RN SNAME Marks
# 0  1.0     A  24.0
# 1  2.0   2.0  28.0
# 2  NaN     C  19.0
# 3  4.0     D  25.0
# 4  NaN     E     E

# %%
df1.ffill(axis=0)
# Out:
#     RN SNAME  Marks
# 0  1.0     A   24.0
# 1  2.0     A   28.0
# 2  2.0     C   19.0
# 3  4.0     D   25.0
# 4  4.0     E   25.0

# %%
df = pd.read_excel("/home/ubuntu/Downloads/Demo1.xlsx")
d = df.groupby('GENDER')
print(d.get_group('M'))
# Out:
#     Sr. no.  Roll No               Name of the Student    DM FDS OOP  CG DELD  \
# 0       1.0   SCOA01                     ALISHA SHEIKH  24.0  27  20  15   16
# 1       2.0   SCOA02         SOHAM JAYYANNTH DESHMUKKH  16.0   9   9  AB   AB
# 2       3.0   SCOA03                SHELAR NEHA NILESH  20.0  23  16  15   15
# 3       4.0   SCOA04                       RIYA JAWALE  18.0  14  11   8   15
# 4       5.0   SCOA05             NARHE VARSHA RAOSAHEB  20.0  24  16  24   20
# 5       6.0   SCOA06           BHUTDA MAHESH SHANTILAL  20.0   9  AB   0   AB
# 6       7.0   SCOA07              JAGTAP HARISH YUVRAJ  22.0  18   3  16    7
# 7       8.0   SCOA08         DESHPANDE SRUSHTI VINAYAK  24.0  20  19  16   23
# 8       9.0   SCOA09              DARWEY RUDRA GUNWANT  22.0  12   9  15    7
# 9      10.0   SCOA10                ERANDE TEJAS DIPAK  24.0  18  11  23   AB
# 10     11.0   SCOA11             TRIPATHI VIKALP VIKAS  18.0  13   7  18   10
# ...

# %%
d.first()
# Out:
#         Sr. no.  Roll No  Name of the Student    DM  FDS  OOP  CG  DELD  \
# GENDER
# F          35.0   SCOA35  PATIL JAYESH KAILAS  18.0   20   17  18     5
# M           1.0   SCOA01        ALISHA SHEIKH  24.0   27   20  15    16
#
#         Unnamed: 9  Unnamed: 10  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# GENDER                           ...
# F              NaN          NaN  ...          NaN          NaN          NaN
# M              NaN          NaN  ...          NaN          NaN          NaN
#
#         Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# GENDER
# F               NaN          NaN          NaN          NaN          NaN
# M               NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 22  Unnamed: 23
# GENDER
# F               NaN         None
# M               NaN         None
#
# [2 rows x 23 columns]

# %%
d.count()
# Out:
#         Sr. no.   Roll No  Name of the Student  DM  FDS  OOP  CG  DELD  \
# GENDER
# F            33        33                   33  33   33   33  33    33
# M            34        34                   34  34   34   34  34    34
#
#         Unnamed: 9  Unnamed: 10  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# GENDER                           ...
# F                0            0  ...            0            0            0
# M                0            0  ...            0            0            0
#
#         Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# GENDER
# F                 0            0            0            0            0
# M                 0            0            0            0            0
#
#         Unnamed: 22  Unnamed: 23
# GENDER
# F                 0            0
# M                 0            0
#
# [2 rows x 23 columns]

# %%
for GENDER, group in d:
    print(f"Group: {GENDER}")
    print(group)
# Out:
# Group: F
#     Sr. no.  Roll No          Name of the Student    DM FDS OOP  CG DELD  \
# 34     35.0   SCOA35          PATIL JAYESH KAILAS  18.0  20  17  18    5
# 35     36.0   SCOA36      SOMA KARTIK DNYANESHWAR  14.0  22  AB  20   14
# 36     37.0   SCOA37         KATKAR SURAJ PRADEEP  16.0  26  13  22   AB
# 37     38.0   SCOA38      THETE SANJIVANI SANTOSH  23.0  19  18  24   23
# 38     39.0   SCOA39          KEDAR PAVAN PRALHAD  12.0  AB  AB  AB   AB
# 39     40.0   SCOA40      SHEWALE PRIYANKA NILESH  20.0  18  AB  AB   AB
# 40     41.0   SCOA41              DEVANSHU SHARMA  20.0  20  25  20   21
# 41     42.0   SCOA42          BAILE MANTHAN VIVEK  22.0  17  AB  17   AB
# 42     43.0   SCOA43           DOLAS ADITYA SUNIL  12.0  20   7  12    9
# 43     44.0   SCOA44  SURYAWANSHI RUDRESH VINAYAK  12.0  17  11  11    7
# 44     45.0   SCOA45               TUPE OM KISHOR   6.0  15   0   8    1
# 45     46.0   SCOA46          MAHAJAN KETAN RAHUL   8.0  10   3  11    5
# ...

# %%
df['DM'].corr(df['DELD'])
# Out:
# 0.4553359113874982

# %%
df['DM'].describe()
# Out:
# count    67.000000
# mean     16.029851
# std       6.276387
# min       0.000000
# 25%      12.000000
# 50%      18.000000
# 75%      20.500000
# max      24.000000
# Name: DM, dtype: float64

# %%
df['DM'].drop_duplicates()
# Out:
# 0     24.0
# 1     16.0
# 2     20.0
# 3     18.0
# 6     22.0
# 16    12.0
# 21    21.0
# 25     8.0
# 27    14.0
# 37    23.0
# 44     6.0
# 48    10.0
# 55     0.0
# 56    19.0
# 61     2.0
# 64     4.0
# 65     1.0
# 67     NaN
# Name: DM, dtype: float64
